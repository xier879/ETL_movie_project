# %%
# Set initial dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Create IMDB Movie DataFrame
IMDB_file = "./IMDB_movies.csv"
IMDB_df = pd.read_csv(IMDB_file, encoding='latin-1')
IMDB_df.head()
# Out:
#    Unnamed: 0      budget                                 company country  \
# 0           0   8000000.0           Columbia Pictures Corporation     USA
# 1           1   6000000.0                      Paramount Pictures     USA
# 2           2  15000000.0                      Paramount Pictures     USA
# 3           3  18500000.0  Twentieth Century Fox Film Corporation     USA
# 4           4   9000000.0                    Walt Disney Pictures     USA
#
#          director      genre        gross                      name rating  \
# 0      Rob Reiner  Adventure   52287414.0               Stand by Me      R
# 1     John Hughes     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13
# 2      Tony Scott     Action  179800601.0                   Top Gun     PG
# 3   James Cameron     Action   85160248.0                    Aliens      R
# 4  Randal Kleiser  Adventure   18564613.0   Flight of the Navigator     PG
#
#    runtime  score               star   votes         writer  year
# 0       89    8.1        Wil Wheaton  299174   Stephen King  1986
# 1      103    7.8  Matthew Broderick  264740    John Hughes  1986
# 2      110    6.9         Tom Cruise  236909       Jim Cash  1986
# 3      137    8.4   Sigourney Weaver  540152  James Cameron  1986
# 4       90    6.9        Joey Cramer   36636  Mark H. Baker  1986

# %%
# Create Bollywood Movie DataFrame
Bolly_file = "./BollywoodMovieDetail.csv"
Bolly_df = pd.read_csv(Bolly_file)
Bolly_df.head()
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
#                                               actors  \
# 0  Govinda | Aishwarya Rai Bachchan | Jackie Shro...
# 1  Aamir Khan | Gracy Singh | Rachel Shelley | Pa...
# 2  Akshay Kumar | Sridevi | Gulshan Grover | Laxm...
# 3  Shah Rukh Khan | Madhuri Dixit | Salman Khan |...
# 4  Shah Rukh Khan | Juhi Chawla | Jackie Shroff |...
#
#                       directors  sequel  hitFlop
# 0                 Deepak Sareen     0.0        2
# 1            Ashutosh Gowariker     0.0        6
# 2  Pankaj Parashar | S.M. Iqbal     0.0        1
# 3                 K.S. Adiyaman     0.0        4
# 4             Shashilal K. Nair     0.0        1

# %%
Bolly_df.columns
# Out:
# Index(['imdbId', 'title', 'releaseYear', 'releaseDate', 'genre', 'writers',
#        'actors', 'directors', 'sequel', 'hitFlop'],
#       dtype='object')

# %%
new_Bolly_df = Bolly_df[['imdbId', 'title', 'releaseYear']]

new_Bolly_df.head()
# Out:
#       imdbId                              title  releaseYear
# 0  tt0118578                             Albela         2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002
# 4  tt0227194                         One 2 Ka 4         2001

# %%
new_Bolly_df.columns
# Out:
# Index(['imdbId', 'title', 'releaseYear'], dtype='object')

# %%
export_csv = new_Bolly_df.to_csv('new_Bollywood_movie.csv',index=False)

# %%
rds_connection_string = "postgres:Zhaoxier879@localhost:5432/movie_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['bollywood_movie']

# %%
# Transform the Bollywood DataFrame
pd.read_sql_query('select * from bollywood_movie', con=engine).head()
# Out:
#       imdbId                              title releaseYear
# 0  tt0118578                             Albela        2001
# 1  tt0169102  Lagaan: Once Upon a Time in India        2001
# 2  tt0187279           Meri Biwi Ka Jawab Nahin        2004
# 3  tt0222024             Hum Tumhare Hain Sanam        2002
# 4  tt0227194                         One 2 Ka 4        2001

# %%
import requests
from pprint import pprint
from config import api_key
import json
base_URL = "http://www.omdbapi.com/?apikey="

#for i in range (0,1000)
#create a list of IMDB id numbers


responses =[]
IMDB_id=[]

# %%
for index, row in new_Bolly_df.iterrows():
        row_data = row["imdbId"]
        Trash_list.append(row_data)
#print(IMDB_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-550dfd280ebb> in <module>
#       1 for index, row in new_Bolly_df.iterrows():
#       2         row_data = row["imdbId"]
# ----> 3         Trash_list.append(row_data)
#       4 #print(IMDB_id)
#
# NameError: name 'Trash_list' is not defined

# %%
#api01-06(bootcamp_classwork)
for i in range (0,6):
    for id in IMDB_id:
        URL= base_URL + api_key + "&i=" + id
        movie_data= requests.get(URL).json()
        responses.append(movie_data)
        pprint(responses) 
        #to get budget list
        #budget_list = [budget for budget in movie_response[""][""]]
# Out:
# [{'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
#           'unable to differentiate between the style of these days and that of '
#           'long time ago. When Ajay is given the post as police ...',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZmZmJlZWItYmQ3MS00NDQ5LThlMjEtMmQzODBjY2ZmYzU3XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'Iqbal Productions',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#   'Released': '02 Jul 2004',
#   'Response': 'True',
#   'Runtime': '150 min',
#   'Title': 'Meri Biwi Ka Jawab Nahin',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '2004',
#   'imdbID': 'tt0187279',
#   'imdbRating': '4.6',
#   'imdbVotes': '619'},
#  {'Actors': 'Shah Rukh Khan, Madhuri Dixit, Salman Khan, Atul Agnihotri',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '30 Mar 2004',
#   'Director': 'K.S. Adiyaman',
#   'Genre': 'Drama, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Gopal's blissful married life with Radha blemishes when Radha gets "
#           'obsessed with the career of her friend, Suraj, who is a singer. '
#           'Ripped apart by jealousy, Gopal deserts Radha.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA1Yjg4MGEtZGMzYy00ZmM0LWJjNjAtMmMxZTZiYTY0ZjJmXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '24 May 2002',
#   'Response': 'True',
#   'Runtime': '174 min',
#   'Title': 'Hum Tumhare Hain Sanam',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'K.S. Adiyaman, Arun Kumar (assistant dialogue), Ashok Mehta '
#             '(assistant dialogue), Reema Rakesh Nath (dialogue)',
#   'Year': '2002',
#   'imdbID': 'tt0222024',
#   'imdbRating': '5.4',
#   'imdbVotes': '6,032'},
#  {'Actors': 'Shah Rukh Khan, Juhi Chawla, Jackie Shroff, Nirmal Pandey',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Shashilal K. Nair',
#   'Genre': 'Action, Comedy, Crime, Drama, Thriller',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "When a cop's partner is killed in the line of duty, he assumed "
#           'guardianship of his orphaned children while investigating the '
#           'murder.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhkMTA4ODMtM2UyOC00ZGZlLWFhMjUtMmExZGIyMjE4YjNkXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SX300.jpg',
#   'Production': 'Eros International',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '30 Mar 2001',
#   'Response': 'True',
#   'Runtime': '169 min',
#   'Title': 'One 2 Ka 4',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Sanjay Chhel, Raaj Kumar Dahima (screenplay), Manoj Lalwani '
#             '(screenplay)',
#   'Year': '2001',
#   'imdbID': 'tt0227194',
#   'imdbRating': '5.4',
#   'imdbVotes': '4,499'},
#  {'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
#           'unable to differentiate between the style of these days and that of '
#           'long time ago. When Ajay is given the post as police ...',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZmZmJlZWItYmQ3MS00NDQ5LThlMjEtMmQzODBjY2ZmYzU3XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'Iqbal Productions',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#   'Released': '02 Jul 2004',
#   'Response': 'True',
#   'Runtime': '150 min',
#   'Title': 'Meri Biwi Ka Jawab Nahin',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '2004',
#   'imdbID': 'tt0187279',
#   'imdbRating': '4.6',
#   'imdbVotes': '619'},
#  {'Actors': 'Shah Rukh Khan, Madhuri Dixit, Salman Khan, Atul Agnihotri',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '30 Mar 2004',
#   'Director': 'K.S. Adiyaman',
#   'Genre': 'Drama, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Gopal's blissful married life with Radha blemishes when Radha gets "
#           'obsessed with the career of her friend, Suraj, who is a singer. '
#           'Ripped apart by jealousy, Gopal deserts Radha.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA1Yjg4MGEtZGMzYy00ZmM0LWJjNjAtMmMxZTZiYTY0ZjJmXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '24 May 2002',
#   'Response': 'True',
#   'Runtime': '174 min',
#   'Title': 'Hum Tumhare Hain Sanam',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'K.S. Adiyaman, Arun Kumar (assistant dialogue), Ashok Mehta '
#             '(assistant dialogue), Reema Rakesh Nath (dialogue)',
#   'Year': '2002',
#   'imdbID': 'tt0222024',
#   'imdbRating': '5.4',
#   'imdbVotes': '6,032'},
#  {'Actors': 'Shah Rukh Khan, Juhi Chawla, Jackie Shroff, Nirmal Pandey',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Shashilal K. Nair',
#   'Genre': 'Action, Comedy, Crime, Drama, Thriller',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "When a cop's partner is killed in the line of duty, he assumed "
#           'guardianship of his orphaned children while investigating the '
#           'murder.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhkMTA4ODMtM2UyOC00ZGZlLWFhMjUtMmExZGIyMjE4YjNkXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SX300.jpg',
#   'Production': 'Eros International',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '30 Mar 2001',
#   'Response': 'True',
#   'Runtime': '169 min',
#   'Title': 'One 2 Ka 4',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Sanjay Chhel, Raaj Kumar Dahima (screenplay), Manoj Lalwani '
#             '(screenplay)',
#   'Year': '2001',
#   'imdbID': 'tt0227194',
#   'imdbRating': '5.4',
#   'imdbVotes': '4,499'},
#  {'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
#           'unable to differentiate between the style of these days and that of '
#           'long time ago. When Ajay is given the post as police ...',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZmZmJlZWItYmQ3MS00NDQ5LThlMjEtMmQzODBjY2ZmYzU3XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'Iqbal Productions',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#   'Released': '02 Jul 2004',
#   'Response': 'True',
#   'Runtime': '150 min',
#   'Title': 'Meri Biwi Ka Jawab Nahin',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '2004',
#   'imdbID': 'tt0187279',
#   'imdbRating': '4.6',
#   'imdbVotes': '619'},
#  {'Actors': 'Shah Rukh Khan, Madhuri Dixit, Salman Khan, Atul Agnihotri',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '30 Mar 2004',
#   'Director': 'K.S. Adiyaman',
#   'Genre': 'Drama, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Gopal's blissful married life with Radha blemishes when Radha gets "
#           'obsessed with the career of her friend, Suraj, who is a singer. '
#           'Ripped apart by jealousy, Gopal deserts Radha.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA1Yjg4MGEtZGMzYy00ZmM0LWJjNjAtMmMxZTZiYTY0ZjJmXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '24 May 2002',
#   'Response': 'True',
#   'Runtime': '174 min',
#   'Title': 'Hum Tumhare Hain Sanam',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'K.S. Adiyaman, Arun Kumar (assistant dialogue), Ashok Mehta '
#             '(assistant dialogue), Reema Rakesh Nath (dialogue)',
#   'Year': '2002',
#   'imdbID': 'tt0222024',
#   'imdbRating': '5.4',
#   'imdbVotes': '6,032'},
#  {'Actors': 'Shah Rukh Khan, Juhi Chawla, Jackie Shroff, Nirmal Pandey',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Shashilal K. Nair',
#   'Genre': 'Action, Comedy, Crime, Drama, Thriller',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "When a cop's partner is killed in the line of duty, he assumed "
#           'guardianship of his orphaned children while investigating the '
#           'murder.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhkMTA4ODMtM2UyOC00ZGZlLWFhMjUtMmExZGIyMjE4YjNkXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SX300.jpg',
#   'Production': 'Eros International',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '30 Mar 2001',
#   'Response': 'True',
#   'Runtime': '169 min',
#   'Title': 'One 2 Ka 4',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Sanjay Chhel, Raaj Kumar Dahima (screenplay), Manoj Lalwani '
#             '(screenplay)',
#   'Year': '2001',
#   'imdbID': 'tt0227194',
#   'imdbRating': '5.4',
#   'imdbVotes': '4,499'},
#  {'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
#           'unable to differentiate between the style of these days and that of '
#           'long time ago. When Ajay is given the post as police ...',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZmZmJlZWItYmQ3MS00NDQ5LThlMjEtMmQzODBjY2ZmYzU3XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'Iqbal Productions',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#   'Released': '02 Jul 2004',
#   'Response': 'True',
#   'Runtime': '150 min',
#   'Title': 'Meri Biwi Ka Jawab Nahin',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '2004',
#   'imdbID': 'tt0187279',
#   'imdbRating': '4.6',
#   'imdbVotes': '619'},
#  {'Actors': 'Shah Rukh Khan, Madhuri Dixit, Salman Khan, Atul Agnihotri',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '30 Mar 2004',
#   'Director': 'K.S. Adiyaman',
#   'Genre': 'Drama, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Gopal's blissful married life with Radha blemishes when Radha gets "
#           'obsessed with the career of her friend, Suraj, who is a singer. '
#           'Ripped apart by jealousy, Gopal deserts Radha.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA1Yjg4MGEtZGMzYy00ZmM0LWJjNjAtMmMxZTZiYTY0ZjJmXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '24 May 2002',
#   'Response': 'True',
#   'Runtime': '174 min',
#   'Title': 'Hum Tumhare Hain Sanam',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'K.S. Adiyaman, Arun Kumar (assistant dialogue), Ashok Mehta '
#             '(assistant dialogue), Reema Rakesh Nath (dialogue)',
#   'Year': '2002',
#   'imdbID': 'tt0222024',
#   'imdbRating': '5.4',
#   'imdbVotes': '6,032'},
#  {'Actors': 'Shah Rukh Khan, Juhi Chawla, Jackie Shroff, Nirmal Pandey',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Shashilal K. Nair',
#   'Genre': 'Action, Comedy, Crime, Drama, Thriller',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "When a cop's partner is killed in the line of duty, he assumed "
#           'guardianship of his orphaned children while investigating the '
#           'murder.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhkMTA4ODMtM2UyOC00ZGZlLWFhMjUtMmExZGIyMjE4YjNkXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SX300.jpg',
#   'Production': 'Eros International',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '30 Mar 2001',
#   'Response': 'True',
#   'Runtime': '169 min',
#   'Title': 'One 2 Ka 4',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Sanjay Chhel, Raaj Kumar Dahima (screenplay), Manoj Lalwani '
#             '(screenplay)',
#   'Year': '2001',
#   'imdbID': 'tt0227194',
#   'imdbRating': '5.4',
#   'imdbVotes': '4,499'},
#  {'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
#           'unable to differentiate between the style of these days and that of '
#           'long time ago. When Ajay is given the post as police ...',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZmZmJlZWItYmQ3MS00NDQ5LThlMjEtMmQzODBjY2ZmYzU3XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'Iqbal Productions',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#   'Released': '02 Jul 2004',
#   'Response': 'True',
#   'Runtime': '150 min',
#   'Title': 'Meri Biwi Ka Jawab Nahin',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '2004',
#   'imdbID': 'tt0187279',
#   'imdbRating': '4.6',
#   'imdbVotes': '619'},
#  {'Actors': 'Shah Rukh Khan, Madhuri Dixit, Salman Khan, Atul Agnihotri',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '30 Mar 2004',
#   'Director': 'K.S. Adiyaman',
#   'Genre': 'Drama, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Gopal's blissful married life with Radha blemishes when Radha gets "
#           'obsessed with the career of her friend, Suraj, who is a singer. '
#           'Ripped apart by jealousy, Gopal deserts Radha.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA1Yjg4MGEtZGMzYy00ZmM0LWJjNjAtMmMxZTZiYTY0ZjJmXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '24 May 2002',
#   'Response': 'True',
#   'Runtime': '174 min',
#   'Title': 'Hum Tumhare Hain Sanam',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'K.S. Adiyaman, Arun Kumar (assistant dialogue), Ashok Mehta '
#             '(assistant dialogue), Reema Rakesh Nath (dialogue)',
#   'Year': '2002',
#   'imdbID': 'tt0222024',
#   'imdbRating': '5.4',
#   'imdbVotes': '6,032'},
#  {'Actors': 'Shah Rukh Khan, Juhi Chawla, Jackie Shroff, Nirmal Pandey',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Shashilal K. Nair',
#   'Genre': 'Action, Comedy, Crime, Drama, Thriller',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "When a cop's partner is killed in the line of duty, he assumed "
#           'guardianship of his orphaned children while investigating the '
#           'murder.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhkMTA4ODMtM2UyOC00ZGZlLWFhMjUtMmExZGIyMjE4YjNkXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SX300.jpg',
#   'Production': 'Eros International',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '30 Mar 2001',
#   'Response': 'True',
#   'Runtime': '169 min',
#   'Title': 'One 2 Ka 4',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Sanjay Chhel, Raaj Kumar Dahima (screenplay), Manoj Lalwani '
#             '(screenplay)',
#   'Year': '2001',
#   'imdbID': 'tt0227194',
#   'imdbRating': '5.4',
#   'imdbVotes': '4,499'},
#  {'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
#           'unable to differentiate between the style of these days and that of '
#           'long time ago. When Ajay is given the post as police ...',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZmZmJlZWItYmQ3MS00NDQ5LThlMjEtMmQzODBjY2ZmYzU3XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'Iqbal Productions',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#   'Released': '02 Jul 2004',
#   'Response': 'True',
#   'Runtime': '150 min',
#   'Title': 'Meri Biwi Ka Jawab Nahin',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '2004',
#   'imdbID': 'tt0187279',
#   'imdbRating': '4.6',
#   'imdbVotes': '619'},
#  {'Actors': 'Shah Rukh Khan, Madhuri Dixit, Salman Khan, Atul Agnihotri',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '30 Mar 2004',
#   'Director': 'K.S. Adiyaman',
#   'Genre': 'Drama, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Gopal's blissful married life with Radha blemishes when Radha gets "
#           'obsessed with the career of her friend, Suraj, who is a singer. '
#           'Ripped apart by jealousy, Gopal deserts Radha.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA1Yjg4MGEtZGMzYy00ZmM0LWJjNjAtMmMxZTZiYTY0ZjJmXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '24 May 2002',
#   'Response': 'True',
#   'Runtime': '174 min',
#   'Title': 'Hum Tumhare Hain Sanam',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'K.S. Adiyaman, Arun Kumar (assistant dialogue), Ashok Mehta '
#             '(assistant dialogue), Reema Rakesh Nath (dialogue)',
#   'Year': '2002',
#   'imdbID': 'tt0222024',
#   'imdbRating': '5.4',
#   'imdbVotes': '6,032'},
#  {'Actors': 'Shah Rukh Khan, Juhi Chawla, Jackie Shroff, Nirmal Pandey',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Shashilal K. Nair',
#   'Genre': 'Action, Comedy, Crime, Drama, Thriller',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "When a cop's partner is killed in the line of duty, he assumed "
#           'guardianship of his orphaned children while investigating the '
#           'murder.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhkMTA4ODMtM2UyOC00ZGZlLWFhMjUtMmExZGIyMjE4YjNkXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SX300.jpg',
#   'Production': 'Eros International',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '30 Mar 2001',
#   'Response': 'True',
#   'Runtime': '169 min',
#   'Title': 'One 2 Ka 4',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Sanjay Chhel, Raaj Kumar Dahima (screenplay), Manoj Lalwani '
#             '(screenplay)',
#   'Year': '2001',
#   'imdbID': 'tt0227194',
#   'imdbRating': '5.4',
#   'imdbVotes': '4,499'},
#  {'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'}]
# [{'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
#           'unable to differentiate between the style of these days and that of '
#           'long time ago. When Ajay is given the post as police ...',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZmZmJlZWItYmQ3MS00NDQ5LThlMjEtMmQzODBjY2ZmYzU3XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'Iqbal Productions',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#   'Released': '02 Jul 2004',
#   'Response': 'True',
#   'Runtime': '150 min',
#   'Title': 'Meri Biwi Ka Jawab Nahin',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '2004',
#   'imdbID': 'tt0187279',
#   'imdbRating': '4.6',
#   'imdbVotes': '619'},
#  {'Actors': 'Shah Rukh Khan, Madhuri Dixit, Salman Khan, Atul Agnihotri',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '30 Mar 2004',
#   'Director': 'K.S. Adiyaman',
#   'Genre': 'Drama, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Gopal's blissful married life with Radha blemishes when Radha gets "
#           'obsessed with the career of her friend, Suraj, who is a singer. '
#           'Ripped apart by jealousy, Gopal deserts Radha.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA1Yjg4MGEtZGMzYy00ZmM0LWJjNjAtMmMxZTZiYTY0ZjJmXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '24 May 2002',
#   'Response': 'True',
#   'Runtime': '174 min',
#   'Title': 'Hum Tumhare Hain Sanam',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'K.S. Adiyaman, Arun Kumar (assistant dialogue), Ashok Mehta '
#             '(assistant dialogue), Reema Rakesh Nath (dialogue)',
#   'Year': '2002',
#   'imdbID': 'tt0222024',
#   'imdbRating': '5.4',
#   'imdbVotes': '6,032'},
#  {'Actors': 'Shah Rukh Khan, Juhi Chawla, Jackie Shroff, Nirmal Pandey',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Shashilal K. Nair',
#   'Genre': 'Action, Comedy, Crime, Drama, Thriller',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "When a cop's partner is killed in the line of duty, he assumed "
#           'guardianship of his orphaned children while investigating the '
#           'murder.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhkMTA4ODMtM2UyOC00ZGZlLWFhMjUtMmExZGIyMjE4YjNkXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SX300.jpg',
#   'Production': 'Eros International',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '30 Mar 2001',
#   'Response': 'True',
#   'Runtime': '169 min',
#   'Title': 'One 2 Ka 4',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Sanjay Chhel, Raaj Kumar Dahima (screenplay), Manoj Lalwani '
#             '(screenplay)',
#   'Year': '2001',
#   'imdbID': 'tt0227194',
#   'imdbRating': '5.4',
#   'imdbVotes': '4,499'},
#  {'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
#           'unable to differentiate between the style of these days and that of '
#           'long time ago. When Ajay is given the post as police ...',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZmZmJlZWItYmQ3MS00NDQ5LThlMjEtMmQzODBjY2ZmYzU3XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'Iqbal Productions',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#   'Released': '02 Jul 2004',
#   'Response': 'True',
#   'Runtime': '150 min',
#   'Title': 'Meri Biwi Ka Jawab Nahin',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '2004',
#   'imdbID': 'tt0187279',
#   'imdbRating': '4.6',
#   'imdbVotes': '619'},
#  {'Actors': 'Shah Rukh Khan, Madhuri Dixit, Salman Khan, Atul Agnihotri',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '30 Mar 2004',
#   'Director': 'K.S. Adiyaman',
#   'Genre': 'Drama, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Gopal's blissful married life with Radha blemishes when Radha gets "
#           'obsessed with the career of her friend, Suraj, who is a singer. '
#           'Ripped apart by jealousy, Gopal deserts Radha.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA1Yjg4MGEtZGMzYy00ZmM0LWJjNjAtMmMxZTZiYTY0ZjJmXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '24 May 2002',
#   'Response': 'True',
#   'Runtime': '174 min',
#   'Title': 'Hum Tumhare Hain Sanam',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'K.S. Adiyaman, Arun Kumar (assistant dialogue), Ashok Mehta '
#             '(assistant dialogue), Reema Rakesh Nath (dialogue)',
#   'Year': '2002',
#   'imdbID': 'tt0222024',
#   'imdbRating': '5.4',
#   'imdbVotes': '6,032'},
#  {'Actors': 'Shah Rukh Khan, Juhi Chawla, Jackie Shroff, Nirmal Pandey',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Shashilal K. Nair',
#   'Genre': 'Action, Comedy, Crime, Drama, Thriller',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "When a cop's partner is killed in the line of duty, he assumed "
#           'guardianship of his orphaned children while investigating the '
#           'murder.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhkMTA4ODMtM2UyOC00ZGZlLWFhMjUtMmExZGIyMjE4YjNkXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SX300.jpg',
#   'Production': 'Eros International',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '30 Mar 2001',
#   'Response': 'True',
#   'Runtime': '169 min',
#   'Title': 'One 2 Ka 4',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Sanjay Chhel, Raaj Kumar Dahima (screenplay), Manoj Lalwani '
#             '(screenplay)',
#   'Year': '2001',
#   'imdbID': 'tt0227194',
#   'imdbRating': '5.4',
#   'imdbVotes': '4,499'},
#  {'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
# ...
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
#           'unable to differentiate between the style of these days and that of '
#           'long time ago. When Ajay is given the post as police ...',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZmZmJlZWItYmQ3MS00NDQ5LThlMjEtMmQzODBjY2ZmYzU3XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'Iqbal Productions',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#   'Released': '02 Jul 2004',
#   'Response': 'True',
#   'Runtime': '150 min',
#   'Title': 'Meri Biwi Ka Jawab Nahin',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '2004',
#   'imdbID': 'tt0187279',
#   'imdbRating': '4.6',
#   'imdbVotes': '619'},
#  {'Actors': 'Shah Rukh Khan, Madhuri Dixit, Salman Khan, Atul Agnihotri',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '30 Mar 2004',
#   'Director': 'K.S. Adiyaman',
#   'Genre': 'Drama, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Gopal's blissful married life with Radha blemishes when Radha gets "
#           'obsessed with the career of her friend, Suraj, who is a singer. '
#           'Ripped apart by jealousy, Gopal deserts Radha.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA1Yjg4MGEtZGMzYy00ZmM0LWJjNjAtMmMxZTZiYTY0ZjJmXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '24 May 2002',
#   'Response': 'True',
#   'Runtime': '174 min',
#   'Title': 'Hum Tumhare Hain Sanam',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'K.S. Adiyaman, Arun Kumar (assistant dialogue), Ashok Mehta '
#             '(assistant dialogue), Reema Rakesh Nath (dialogue)',
#   'Year': '2002',
#   'imdbID': 'tt0222024',
#   'imdbRating': '5.4',
#   'imdbVotes': '6,032'},
#  {'Actors': 'Shah Rukh Khan, Juhi Chawla, Jackie Shroff, Nirmal Pandey',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Shashilal K. Nair',
#   'Genre': 'Action, Comedy, Crime, Drama, Thriller',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "When a cop's partner is killed in the line of duty, he assumed "
#           'guardianship of his orphaned children while investigating the '
#           'murder.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhkMTA4ODMtM2UyOC00ZGZlLWFhMjUtMmExZGIyMjE4YjNkXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SX300.jpg',
#   'Production': 'Eros International',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '30 Mar 2001',
#   'Response': 'True',
#   'Runtime': '169 min',
#   'Title': 'One 2 Ka 4',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Sanjay Chhel, Raaj Kumar Dahima (screenplay), Manoj Lalwani '
#             '(screenplay)',
#   'Year': '2001',
#   'imdbID': 'tt0227194',
#   'imdbRating': '5.4',
#   'imdbVotes': '4,499'},
#  {'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
#           'unable to differentiate between the style of these days and that of '
#           'long time ago. When Ajay is given the post as police ...',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZmZmJlZWItYmQ3MS00NDQ5LThlMjEtMmQzODBjY2ZmYzU3XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'Iqbal Productions',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#   'Released': '02 Jul 2004',
#   'Response': 'True',
#   'Runtime': '150 min',
#   'Title': 'Meri Biwi Ka Jawab Nahin',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '2004',
#   'imdbID': 'tt0187279',
#   'imdbRating': '4.6',
#   'imdbVotes': '619'},
#  {'Actors': 'Shah Rukh Khan, Madhuri Dixit, Salman Khan, Atul Agnihotri',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '30 Mar 2004',
#   'Director': 'K.S. Adiyaman',
#   'Genre': 'Drama, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Gopal's blissful married life with Radha blemishes when Radha gets "
#           'obsessed with the career of her friend, Suraj, who is a singer. '
#           'Ripped apart by jealousy, Gopal deserts Radha.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA1Yjg4MGEtZGMzYy00ZmM0LWJjNjAtMmMxZTZiYTY0ZjJmXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '24 May 2002',
#   'Response': 'True',
#   'Runtime': '174 min',
#   'Title': 'Hum Tumhare Hain Sanam',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'K.S. Adiyaman, Arun Kumar (assistant dialogue), Ashok Mehta '
#             '(assistant dialogue), Reema Rakesh Nath (dialogue)',
#   'Year': '2002',
#   'imdbID': 'tt0222024',
#   'imdbRating': '5.4',
#   'imdbVotes': '6,032'},
#  {'Actors': 'Shah Rukh Khan, Juhi Chawla, Jackie Shroff, Nirmal Pandey',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Shashilal K. Nair',
#   'Genre': 'Action, Comedy, Crime, Drama, Thriller',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "When a cop's partner is killed in the line of duty, he assumed "
#           'guardianship of his orphaned children while investigating the '
#           'murder.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhkMTA4ODMtM2UyOC00ZGZlLWFhMjUtMmExZGIyMjE4YjNkXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SX300.jpg',
#   'Production': 'Eros International',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '30 Mar 2001',
#   'Response': 'True',
#   'Runtime': '169 min',
#   'Title': 'One 2 Ka 4',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Sanjay Chhel, Raaj Kumar Dahima (screenplay), Manoj Lalwani '
#             '(screenplay)',
#   'Year': '2001',
#   'imdbID': 'tt0227194',
#   'imdbRating': '5.4',
#   'imdbVotes': '4,499'},
#  {'Actors': 'Govinda, Aishwarya Rai Bachchan, Jackie Shroff, Namrata Shirodkar',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Deepak Sareen',
#   'Genre': 'N/A',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Boy is loved by a girl, but he doesn't know. Boy becomes smitten "
#           'with another girl, but she loves another.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM5MDM1ODA5MF5BMl5BanBnXkFtZTgwNTkyODY4MzE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'UNRATED',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#   'Released': '20 Apr 2001',
#   'Response': 'True',
#   'Runtime': '145 min',
#   'Title': 'Albela',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Honey Irani (screenplay), Honey Irani (story), Javed Siddiqui '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0118578',
#   'imdbRating': '3.6',
#   'imdbVotes': '608'},
#  {'Actors': 'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#   'Awards': 'Nominated for 1 Oscar. Another 50 wins & 19 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '22 Jan 2002',
#   'Director': 'Ashutosh Gowariker',
#   'Genre': 'Adventure, Drama, Musical, Sport',
#   'Language': 'Hindi, English, Awadhi, Urdu',
#   'Metascore': '84',
#   'Plot': 'The people of a small village in Victorian India stake their future '
#           'on a game of cricket against their ruthless British rulers.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Production': 'B4U Entertainment',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Released': '15 Jun 2001',
#   'Response': 'True',
#   'Runtime': '224 min',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), '
#             'Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena '
#             '(dialogue)',
#   'Year': '2001',
#   'imdbID': 'tt0169102',
#   'imdbRating': '8.1',
#   'imdbVotes': '96,309'},
#  {'Actors': 'Akshay Kumar, Sridevi, Gulshan Grover, Laxmikant Berde',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '25 Oct 2005',
#   'Director': 'Pankaj Parashar, S.M. Iqbal',
#   'Genre': 'Action, Comedy, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': 'Ajay gets married to his childhood friend Durga; who is illiterate '
#           'unable to differentiate between the style of these days and that of '
#           'long time ago. When Ajay is given the post as police ...',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZmZmJlZWItYmQ3MS00NDQ5LThlMjEtMmQzODBjY2ZmYzU3XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'Iqbal Productions',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#   'Released': '02 Jul 2004',
#   'Response': 'True',
#   'Runtime': '150 min',
#   'Title': 'Meri Biwi Ka Jawab Nahin',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'N/A',
#   'Year': '2004',
#   'imdbID': 'tt0187279',
#   'imdbRating': '4.6',
#   'imdbVotes': '619'},
#  {'Actors': 'Shah Rukh Khan, Madhuri Dixit, Salman Khan, Atul Agnihotri',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': '30 Mar 2004',
#   'Director': 'K.S. Adiyaman',
#   'Genre': 'Drama, Romance',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "Gopal's blissful married life with Radha blemishes when Radha gets "
#           'obsessed with the career of her friend, Suraj, who is a singer. '
#           'Ripped apart by jealousy, Gopal deserts Radha.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA1Yjg4MGEtZGMzYy00ZmM0LWJjNjAtMmMxZTZiYTY0ZjJmXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '24 May 2002',
#   'Response': 'True',
#   'Runtime': '174 min',
#   'Title': 'Hum Tumhare Hain Sanam',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'K.S. Adiyaman, Arun Kumar (assistant dialogue), Ashok Mehta '
#             '(assistant dialogue), Reema Rakesh Nath (dialogue)',
#   'Year': '2002',
#   'imdbID': 'tt0222024',
#   'imdbRating': '5.4',
#   'imdbVotes': '6,032'},
#  {'Actors': 'Shah Rukh Khan, Juhi Chawla, Jackie Shroff, Nirmal Pandey',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'India',
#   'DVD': 'N/A',
#   'Director': 'Shashilal K. Nair',
#   'Genre': 'Action, Comedy, Crime, Drama, Thriller',
#   'Language': 'Hindi',
#   'Metascore': 'N/A',
#   'Plot': "When a cop's partner is killed in the line of duty, he assumed "
#           'guardianship of his orphaned children while investigating the '
#           'murder.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhkMTA4ODMtM2UyOC00ZGZlLWFhMjUtMmExZGIyMjE4YjNkXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SX300.jpg',
#   'Production': 'Eros International',
#   'Rated': 'Not Rated',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#   'Released': '30 Mar 2001',
#   'Response': 'True',
#   'Runtime': '169 min',
#   'Title': 'One 2 Ka 4',
#   'Type': 'movie',
#   'Website': 'N/A',
#   'Writer': 'Sanjay Chhel, Raaj Kumar Dahima (screenplay), Manoj Lalwani '
#             '(screenplay)',
#   'Year': '2001',
#   'imdbID': 'tt0227194',
#   'imdbRating': '5.4',
#   'imdbVotes': '4,499'}]
